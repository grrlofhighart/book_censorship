# %% [markdown]
# # How I Collected the ALA Banned Book Data

# %% [markdown]
# By [Crystal Shearer](https://grrlofhighart.github.io/)

# %% [markdown]
# This notebook outlines my process for collecting and cleaning ALA Banned Book Data from the ALA website. The Office for Intellectual Freedom Americal Library Association compiles a list each year of the Top 10 most challenged books. Lists from 2001 thru 2023 are housed at https://www.ala.org/bbooks/frequentlychallengedbooks/top10/archive.

# %% [markdown]
# I was interested in trying out different collection methods throughout my project, so I decided to start with what seemed like the most simple method....Google Sheets. Since the data on the ALA website is formatted as an ordered list I was able to utilize the IMPORTHTML function. I'll also be working with a large dataset that requires sqlite, so I'll be transferring the ALA book data to my sql database for later analysis.

# %% [markdown]
# ### Step 1: Importing all the necessary Libraries

# %%
# pandas for data manipulation
import pandas as pd
# sqlite3 for storage of the dataset
import sqlite3
from contextlib import closing
# re for working with regular expressions (strings)
import re

# %% [markdown]
# ### Step 2: Importing the Google Sheet

# %%
# Function to convert Google Sheets url to a csv export url.
def convert_google_sheet_url(url):
    # Regular expression to match and capture the necessary part of the URL
    pattern = r'https://docs\.google\.com/spreadsheets/d/([a-zA-Z0-9-_]+)(/edit#gid=(\d+)|/edit.*)?'

    # Replace function to construct the new URL for CSV export
    # If gid is present in the URL, it includes it in the export URL, otherwise, it's omitted
    replacement = lambda m: f'https://docs.google.com/spreadsheets/d/{m.group(1)}/export?' + (f'gid={m.group(3)}&' if m.group(3) else '') + 'format=csv'

    # Replace using regex
    new_url = re.sub(pattern, replacement, url)

    return new_url

# %%
# URL to my Google Sheet with book data imported using IMPORTHTML function
url = 'https://docs.google.com/spreadsheets/d/1Ef1j2eAi6eGx7iF9ItePMEbQr6PqvfwSmpaHKLEo-5Q/edit?gid=1299874103#gid=1299874103'

# Updated URL
updated_url = convert_google_sheet_url(url)

# Pull info from Google Sheet into dataframe
df = pd.read_csv(updated_url)
df.head()
# Out:
#                                                 2023  \
# 0  Gender Queer: A Memoir; Maia Kobabe; Reasons: ...
# 1  All Boys Aren't Blue: A Memoir-Manifesto; Geor...
# 2  This Book is Gay; Juno Dawson; Reasons: LGBTQI...
# 3  The Perks of Being a Wallflower; Stephen Chbos...
# 4  Flamer; Mike Curato; Reasons: LGBTQIA+ content...
#
#                                                 2022  \
# 0  Gender Queer: A Memoir; Maia Kobabe; Reasons: ...
# 1  All Boys Aren't Blue: A Memoir-Manifesto; Geor...
# 2  The Bluest Eye; Toni Morrison; Reasons: Banned...
# 3  Flamer; Mike Curato; Reasons:Banned and challe...
# 4  Looking for Alaska; John Green; Reasons: Banne...
#
#                                                 2021  \
# 0  Gender Queer: A Memoir; Maia Kobabe; Reasons: ...
# 1  Lawn Boy; Jonathan Evison; Reasons: Banned and...
# 2  All Boys Aren't Blue: A Memoir-Manifesto; Geor...
# 3  Out of Darkness; Ashley Hope Perez; Reasons: B...
# 4  The Hate U Give; Angie Thomas; Reasons: Banned...
\
# 0  And Tango Makes Three; Justin Richardson and P...
# 1  His Dark Materials; Philip Pullman; Reasons: p...
# 2  ttyl; ttfn; l8r, g8r; Lauren Myracle; Reasons:...
# 3  Scary Stories to Tell in the Dark; Alvin Schwa...
# 4  Bless Me Ultima; Rudolfo Anaya; Reasons: occul...
#
#                                                 2007  \
# 0  And Tango Makes Three; Justin Richardson and P...
# 1  The Chocolate War; Robert Cormier; Reasons: of...
# 2  Olive's Ocean; Kevin Henkes; Reasons: offensiv...
# 3  The Golden Compass; Philip Pullman; Reasons: r...
# 4  The Adventures of Huckleberry Finn; Mark Twain...
#
#                                                 2006  \
# 0  And Tango Makes Three; Justin Richardson and P...
# 1  Gossip Girl; Cecily Von Ziegesar; Reasons: hom...
# 2  The Agony of Alice; Phyllis Reynolds Naylor; R...
# 3  The Earth, My Butt, and Other Big Round Things...
# 4  The Bluest Eye; Toni Morrison; Reasons: offens...
#
#                                                 2005  \
# 0  It's Perfectly Normal: Changing Bodies, Growin...
# 1  Forever; Judy Blume; Reasons: offensive langua...
# 2  The Catcher in the Rye; J. D. Salinger; Reason...
# 3  The Chocolate War; Robert Cormier; Reasons: se...
# 4  Whale Talk; Chris Crutcher; Reasons: racism, o...
#
#                                                 2004  \
# 0  The Chocolate War; Robert Cormier; Reasons: of...
# 1  Fallen Angels; Walter Dean Myers; Reasons: off...
# 2  Arming America: The Origins of a National Gun ...
# 3  The Adventures Of Captain Underpants; Dav Pilk...
# 4  The Perks of Being a Wallflower; Stephen Chbos...
#
#                                                 2003  \
# 0  The Agony of Alice; Phyllis Reynolds Naylor; R...
# 1  Harry Potter Series Box Set; J.K. Rowling; Rea...
# 2  Of Mice and Men; John Steinbeck; Reasons: offe...
# 3  Arming America: The Origins of a National Gun ...
# 4  Fallen Angels; Walter Dean Myers; Reasons: dru...
#
#                                                 2002  \
# 0  Harry Potter Series Box Set; J.K. Rowling; Rea...
# 1  The Agony of Alice; Phyllis Reynolds Naylor; R...
# 2  The Chocolate War; Robert Cormier; Reasons: of...
# 3  I Know Why the Caged Bird Sings; Maya Angelou;...
# 4  Taming the Star Runner; S.E. Hinton; Reasons: ...
#
#                                                 2001
# 0  Harry Potter Series Box Set; J.K. Rowling; Rea...
# 1  Of Mice and Men; John Steinbeck; Reasons: offe...
# 2  The Chocolate War; Robert Cormier; Reasons: of...
# 3  I Know Why the Caged Bird Sings; Maya Angelou;...
# 4  Summer of My German Soldier; Bette Greene; Rea...
#
# [5 rows x 23 columns]

# %%
# Replace NaN values with 'None' to avoid error
df = df.replace({float('nan'): 'None; None; None'})

# Remove special characters
df = df.map(lambda x: re.sub(r'[\'\.+\`\|\#\:\’\*+]', '', x))
# df = df.map(lambda x: re.sub(r'[\-]', ' ', x))

# Remove parentheses and information within from dataframe
df = df.map(lambda x: re.sub(r'\([^()]*\)', '', x))

# Preview dataframe
df.head()
# Out:
#                                                 2023  \
# 0  Gender Queer A Memoir; Maia Kobabe; Reasons LG...
# 1  All Boys Arent Blue A Memoir-Manifesto; George...
# 2  This Book is Gay; Juno Dawson; Reasons LGBTQIA...
# 3  The Perks of Being a Wallflower; Stephen Chbos...
# 4  Flamer; Mike Curato; Reasons LGBTQIA content, ...
#
#                                                 2022  \
# 0  Gender Queer A Memoir; Maia Kobabe; Reasons Ba...
# 1  All Boys Arent Blue A Memoir-Manifesto; George...
# 2  The Bluest Eye; Toni Morrison; Reasons Banned ...
\
# 0  And Tango Makes Three; Justin Richardson and P...
# 1  His Dark Materials; Philip Pullman; Reasons po...
# 2  ttyl; ttfn; l8r, g8r; Lauren Myracle; Reasons ...
# 3  Scary Stories to Tell in the Dark; Alvin Schwa...
# 4  Bless Me Ultima; Rudolfo Anaya; Reasons occult...
#
#                                                 2007  \
# 0  And Tango Makes Three; Justin Richardson and P...
# 1  The Chocolate War; Robert Cormier; Reasons off...
# 2  Olives Ocean; Kevin Henkes; Reasons offensive ...
# 3  The Golden Compass; Philip Pullman; Reasons re...
# 4  The Adventures of Huckleberry Finn; Mark Twain...
#
#                                                 2006  \
# 0  And Tango Makes Three; Justin Richardson and P...
# 1  Gossip Girl; Cecily Von Ziegesar; Reasons homo...
# 2  The Agony of Alice; Phyllis Reynolds Naylor; R...
# 3  The Earth, My Butt, and Other Big Round Things...
# 4  The Bluest Eye; Toni Morrison; Reasons offensi...
#
#                                                 2005  \
# 0  Its Perfectly Normal Changing Bodies, Growing ...
# 1  Forever; Judy Blume; Reasons offensive languag...
# 2  The Catcher in the Rye; J. D. Salinger; Reason...
# 3  The Chocolate War; Robert Cormier; Reasons sex...
# 4  Whale Talk; Chris Crutcher; Reasons racism, of...
#
#                                                 2004  \
# 0  The Chocolate War; Robert Cormier; Reasons off...
# 1  Fallen Angels; Walter Dean Myers; Reasons offe...
# 2  Arming America The Origins of a National Gun C...
# 3  The Adventures Of Captain Underpants; Dav Pilk...
# 4  The Perks of Being a Wallflower; Stephen Chbos...
#
#                                                 2003  \
# 0  The Agony of Alice; Phyllis Reynolds Naylor; R...
# 1  Harry Potter Series Box Set; J.K. Rowling; Rea...
# 2  Of Mice and Men; John Steinbeck; Reasons offen...
# 3  Arming America The Origins of a National Gun C...
# 4  Fallen Angels; Walter Dean Myers; Reasons drug...
#
#                                                 2002  \
# 0  Harry Potter Series Box Set; J.K. Rowling; Rea...
# 1  The Agony of Alice; Phyllis Reynolds Naylor; R...
# 2  The Chocolate War; Robert Cormier; Reasons off...
# 3  I Know Why the Caged Bird Sings; Maya Angelou;...
# 4  Taming the Star Runner; S.E. Hinton; Reasons o...
#
#                                                 2001
# 0  Harry Potter Series Box Set; J.K. Rowling; Rea...
# 1  Of Mice and Men; John Steinbeck; Reasons offen...
# 2  The Chocolate War; Robert Cormier; Reasons off...
# 3  I Know Why the Caged Bird Sings; Maya Angelou;...
# 4  Summer of My German Soldier; Bette Greene; Rea...
#
# [5 rows x 23 columns]

# %% [markdown]
# ### Step 3: Setting up the Database

# %% [markdown]
# I plan on collecting multiple datasets, one of which I expect will be quite large. To keep everything uniform I decided to store my data in a sql database.

# %%
# Setup SQLite Database to store data
database = 'Book_DB.db'
conn = sqlite3.connect(database)
c = conn.cursor()

# %%
# Transfer copy of original dataframe to database
df.to_sql(name='ala_top_10_archive_original', con=conn, if_exists='replace', index=False)
# df.to_csv('ala_top_10_archive_original.csv', index=False)
# Out:
# 13

# %% [markdown]
# ### Step 4: Cleaning the ALA Book Data

# %% [markdown]
# In its current form the dataframe is pretty useless. I'd like to separate out the book title, author, and challenge reasons into their own columns while keeping the years and order intact for each.

# %%
# Import table from sql database as dataframe
query = 'SELECT * FROM ala_top_10_archive_original'
sql_df = pd.read_sql(sql=query, con=conn)

# Preview dataframe
sql_df.head()
# Out:
#                                                 2023  \
# 0  Gender Queer A Memoir; Maia Kobabe; Reasons LG...
# 1  All Boys Arent Blue A Memoir-Manifesto; George...
# 2  This Book is Gay; Juno Dawson; Reasons LGBTQIA...
# 3  The Perks of Being a Wallflower; Stephen Chbos...
# 4  Flamer; Mike Curato; Reasons LGBTQIA content, ...
#
#                                                 2022  \
# 0  Gender Queer A Memoir; Maia Kobabe; Reasons Ba...
# 1  All Boys Arent Blue A Memoir-Manifesto; George...
# 2  The Bluest Eye; Toni Morrison; Reasons Banned ...
# 3  Flamer; Mike Curato; ReasonsBanned and challen...
# 4  Looking for Alaska; John Green; Reasons Banned...
#
#                                                 2021  \
# 0  Gender Queer A Memoir; Maia Kobabe; Reasons Ba...
# 1  Lawn Boy; Jonathan Evison; Reasons Banned and ...
# 2  All Boys Arent Blue A Memoir-Manifesto; George...
# 3  Out of Darkness; Ashley Hope Perez; Reasons Ba...
# 4  The Hate U Give; Angie Thomas; Reasons Banned ...
#
#                                                 2020  \
# 0  George; Alex Gino; Reasons Challenged, banned,...
# 1  Stamped Racism, Antiracism, and You; Ibram X. ...
# 2  All American Boys; Jason Reynolds and Brendan ...
# 3  Speak; Laurie Halse Anderson; Reasons Banned, ...
# 4  The Absolutely True Diary of a Part-Time India...
#
#                                                 2019  \
# 0  George; Alex Gino; Reasons challenged, banned,...
# 1  Beyond Magenta Transgender and Nonbinary Teens...
# 2  A Day in the Life of Marlon Bundo; Jill Twiss;...
# 3  Sex Is a Funny Word A Book about Bodies, Feeli...
# 4  Prince & Knight; Daniel Haack; Reasons challen...
#
#                                                 2018  \
# 0  George; Alex Gino; Reasons banned, challenged,...
# 1  A Day in the Life of Marlon Bundo; Jill Twiss;...
# 2  The Adventures Of Captain Underpants; Dav Pilk...
# 3  The Hate U Give; Angie Thomas; Reasons banned ...
# 4  Drama; Raina Telgemeier; Reasons banned and ch...
#
#                                                 2017  \
# 0  Thirteen Reasons Why; Jay Asher; Reasons Origi...
# 1  The Absolutely True Diary of a Part-Time India...
# 2  Drama; Raina Telgemeier; Reasons This Stonewal...
# 3  The Kite Runner; Khaled Hosseini; Reasons This...
# 4  George; Alex Gino; Reasons Written for element...
#
#                                                 2016  \
# 0  This One Summer; Mariko Tamaki; Reasons challe...
# 1  Drama; Raina Telgemeier; Reasons challenged be...
# 2  George; Alex Gino; Reasons challenged because ...
# 3  I Am Jazz; Jessica Herthel and Jazz Jennings; ...
# 4  Two Boys Kissing; David Levithan; Reasons chal...
#
#                                                 2015  \
# 0  Looking for Alaska; John Green; Reasons offens...
# 1  Fifty Shades of Grey; E. L. James; Reasons sex...
# 2  I Am Jazz; Jessica Herthel and Jazz Jennings; ...
# 3  Beyond Magenta Transgender and Nonbinary Teens...
Harry Potter Series Box Set; J.K. Rowling; Rea...
# 1  The Agony of Alice; Phyllis Reynolds Naylor; R...
# 2  The Chocolate War; Robert Cormier; Reasons off...
# 3  I Know Why the Caged Bird Sings; Maya Angelou;...
# 4  Taming the Star Runner; S.E. Hinton; Reasons o...
#
#                                                 2001
# 0  Harry Potter Series Box Set; J.K. Rowling; Rea...
# 1  Of Mice and Men; John Steinbeck; Reasons offen...
# 2  The Chocolate War; Robert Cormier; Reasons off...
# 3  I Know Why the Caged Bird Sings; Maya Angelou;...
# 4  Summer of My German Soldier; Bette Greene; Rea...
#
# [5 rows x 23 columns]

# %%
# Stack all columns of the dataframe
df_stack = sql_df.melt()

# Preview stacked dataframe
df_stack.head()
# Out:
#   variable                                              value
# 0     2023  Gender Queer A Memoir; Maia Kobabe; Reasons LG...
# 1     2023  All Boys Arent Blue A Memoir-Manifesto; George...
# 2     2023  This Book is Gay; Juno Dawson; Reasons LGBTQIA...
# 3     2023  The Perks of Being a Wallflower; Stephen Chbos...
# 4     2023  Flamer; Mike Curato; Reasons LGBTQIA content, ...

# %%
# Rename columns to make them easier to work with
df_stack = df_stack.rename(columns={'variable': 'year', 'value': 'drop1'})
# df_stack = df_stack[df_stack['drop1'] != ('None')]
df_stack
# Out:
#      year                                              drop1
# 0    2023  Gender Queer A Memoir; Maia Kobabe; Reasons LG...
# 1    2023  All Boys Arent Blue A Memoir-Manifesto; George...
# 2    2023  This Book is Gay; Juno Dawson; Reasons LGBTQIA...
# 3    2023  The Perks of Being a Wallflower; Stephen Chbos...
# 4    2023  Flamer; Mike Curato; Reasons LGBTQIA content, ...
# ..    ...                                                ...
# 294  2001  Fallen Angels; Walter Dean Myers; Reasons offe...
# 295  2001  Blood and Chocolate; Annette Curtis Klause; Re...
# 296  2001                                   None; None; None
# 297  2001                                   None; None; None
# 298  2001                                   None; None; None
#
# [299 rows x 2 columns]

# %%
# Function to split column once on the ';' value
def split_column(name):
    return pd.Series(name.split(";", 1))

# %%
# Apply the split function to the "drop1" column using apply()
# Name the new columns accordingly
df_stack[['title', 'drop2']] = df_stack['drop1'].apply(split_column)

# Apply the split function to the new drop2 column using apply()
# Name the new columns accordingly
df_stack[['author', 'reasons']] = df_stack['drop2'].apply(split_column)
 
# Drop the columns labled with 'drop' since they are no longer needed 
df_stack.drop(columns=['drop1', 'drop2'], inplace=True)
df_stack
# Out:
#      year                                   title                  author  \
# 0    2023                   Gender Queer A Memoir             Maia Kobabe
# 1    2023  All Boys Arent Blue A Memoir-Manifesto       George M. Johnson
# 2    2023                        This Book is Gay             Juno Dawson
# 3    2023         The Perks of Being a Wallflower         Stephen Chbosky
# 4    2023                                  Flamer             Mike Curato
# ..    ...                                     ...                     ...
# 294  2001                           Fallen Angels       Walter Dean Myers
# 295  2001                     Blood and Chocolate   Annette Curtis Klause
# 296  2001                                    None                    None
# 297  2001                                    None                    None
# 298  2001                                    None                    None
#
#                                                reasons
# 0     Reasons LGBTQIA content, claimed to be sexual...
# 1     Reasons LGBTQIA content, claimed to be sexual...
# 2     Reasons LGBTQIA content, sex education, claim...
# 3     Reasons claimed to be sexually explicit, LGBT...
# 4     Reasons LGBTQIA content, claimed to be sexual...
# ..                                                 ...
# 294                         Reasons offensive language
# 295   Reasons sexually explicit, unsuited to age group
# 296                                               None
# 297                                               None
# 298                                               None
#
# [299 rows x 4 columns]

# %%
# Drop the rows containing 'None' values
df_stack = df_stack[df_stack['title'] != ('None')]
df_stack
# Out:
#      year                                   title                    author  \
# 0    2023                   Gender Queer A Memoir               Maia Kobabe
# 1    2023  All Boys Arent Blue A Memoir-Manifesto         George M. Johnson
# 2    2023                        This Book is Gay               Juno Dawson
# 3    2023         The Perks of Being a Wallflower           Stephen Chbosky
# 4    2023                                  Flamer               Mike Curato
# ..    ...                                     ...                       ...
# 291  2001                  The Catcher in the Rye             J.D. Salinger
# 292  2001                      The Agony of Alice   Phyllis Reynolds Naylor
# 293  2001                            Go Ask Alice                 Anonymous
# 294  2001                           Fallen Angels         Walter Dean Myers
# 295  2001                     Blood and Chocolate     Annette Curtis Klause
#
#                                                reasons
# 0     Reasons LGBTQIA content, claimed to be sexual...
# 1     Reasons LGBTQIA content, claimed to be sexual...
# 2     Reasons LGBTQIA content, sex education, claim...
# 3     Reasons claimed to be sexually explicit, LGBT...
# 4     Reasons LGBTQIA content, claimed to be sexual...
# ..                                                 ...
# 291   Reasons offensive language, unsuited to age g...
# 292   Reasons sexually explicit, unsuited to age group
# 293   Reasons drugs, offensive language, sexually e...
# 294                         Reasons offensive language
# 295   Reasons sexually explicit, unsuited to age group
#
# [234 rows x 4 columns]

# %%
# Trim leading/trailing whitespace from dataframe
df_stack = df_stack.apply(lambda x: x.str.strip() if x.dtype == "object" else x)
df_stack
# Out:
#      year                                   title                   author  \
# 0    2023                   Gender Queer A Memoir              Maia Kobabe
# 1    2023  All Boys Arent Blue A Memoir-Manifesto        George M. Johnson
# 2    2023                        This Book is Gay              Juno Dawson
# 3    2023         The Perks of Being a Wallflower          Stephen Chbosky
# 4    2023                                  Flamer              Mike Curato
# ..    ...                                     ...                      ...
# 291  2001                  The Catcher in the Rye            J.D. Salinger
# 292  2001                      The Agony of Alice  Phyllis Reynolds Naylor
# 293  2001                            Go Ask Alice                Anonymous
# 294  2001                           Fallen Angels        Walter Dean Myers
# 295  2001                     Blood and Chocolate    Annette Curtis Klause
#
#                                                reasons
# 0    Reasons LGBTQIA content, claimed to be sexuall...
# 1    Reasons LGBTQIA content, claimed to be sexuall...
# 2    Reasons LGBTQIA content, sex education, claime...
# 3    Reasons claimed to be sexually explicit, LGBTQ...
# 4    Reasons LGBTQIA content, claimed to be sexuall...
# ..                                                 ...
# 291  Reasons offensive language, unsuited to age group
# 292   Reasons sexually explicit, unsuited to age group
# 293  Reasons drugs, offensive language, sexually ex...
# 294                         Reasons offensive language
# 295   Reasons sexually explicit, unsuited to age group
#
# [234 rows x 4 columns]

# %% [markdown]
# ### Step 5: Save the clean data to the database for later

# %%
# Transfer cleaned dataframe to database
df_stack.to_sql(name='ala_top_10_archive_clean', con=conn, if_exists='replace', index=False)
# Out:
# 234

# %%
# Close database connection
conn.close()
